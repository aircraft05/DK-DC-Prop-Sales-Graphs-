# %%
import pandas as pd
import numpy as np

location = "downloads/datasets/DC_Properties.csv"
df = pd.read_csv(location)

df.head()
# Out:
# C:\Users\D\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df['ROOMS'].max()
# Out:
# 48

# %%
df['ROOMS'].min()
# Out:
# 0

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df.groupby(['ZIPCODE','PRICE','BEDRM']).mean()
# Out:
#                          Unnamed: 0  BATHRM  HF_BATHRM  NUM_UNITS  ROOMS  \
# ZIPCODE PRICE     BEDRM
# 20001.0 1.0       1        148694.0     1.0        0.0        NaN    3.0
#         250.0     2         49443.0     2.0        0.0        2.0    8.0
#                   5         55048.0     3.0        0.0        1.0    9.0
#                   6         54909.0     5.0        2.0        2.0   10.0
#         500.0     2         49470.0     2.0        0.0        2.0    6.0
#                   4         57413.0     3.0        0.5        2.0    8.0
#                   7          5516.0     2.0        1.0        2.0   15.0
#         936.0     4          3330.0     2.0        1.0        1.0    9.0
#         5000.0    3         54953.0     2.0        1.0        2.0    6.0
#         5643.0    1        157136.0     1.0        1.0        NaN    3.0
#         6000.0    1        134589.0     1.0        0.0        NaN    3.0
# ...

# %%
pd.pivot_table(df, index=['ZIPCODE'])
# Out:
#                  AYB    BATHRM     BEDRM  BLDG_NUM  CENSUS_TRACT    CMPLX_NUM  \
# ZIPCODE
# 20001.0  1944.296908  1.752109  2.515594  1.000569   4426.667457  3075.659109
# 20002.0  1924.439656  1.807051  2.898774  1.000307   8574.291723  3202.751887
# 20003.0  1927.502625  1.877355  2.767187  1.000624   6845.625702  3056.194976
# 20004.0  1999.966728  1.260628  1.208872  1.000000   5800.000000  3065.667283
# 20005.0  1959.517920  1.433608  1.375147  1.000000   5681.060223  2648.242929
# 20006.0  1959.491525  1.025424  0.220339  1.000000  10800.000000  2025.000000
# 20007.0  1936.747423  2.229815  2.901429  1.001661    384.865766  2410.201071
# 20008.0  1940.429981  2.264961  2.824291  1.001323   1399.151889  1563.928487
# 20009.0  1932.782506  1.677625  2.101359  1.000152   4126.949283  2156.422629
# 20010.0  1922.907676  1.877411  3.019757  1.000000   2900.932638  2570.695490
# 20011.0  1933.187243  1.763760  3.216365  1.000183   3541.576994  3125.653263
# ...

# %%
pd.pivot_table(df, values=['PRICE'], index =['ZIPCODE'])
# Out:
#                 PRICE
# ZIPCODE
# 20001.0  5.215550e+05
# 20002.0  4.628894e+05
# 20003.0  5.992484e+05
# 20004.0  4.755701e+05
# 20005.0  2.813137e+06
# 20006.0  1.959069e+05
# 20007.0  9.794061e+05
# 20008.0  8.522766e+05
# 20009.0  6.215259e+05
# 20010.0  5.070154e+05
# 20011.0  4.259763e+05
# 20012.0  4.755227e+05
# 20015.0  7.703746e+05
# 20016.0  5.914537e+06
# 20017.0  4.087405e+05
# 20018.0  3.691101e+05
# 20019.0  2.302621e+05
# 20020.0  2.281464e+05
# 20024.0  3.808846e+05
# 20032.0  3.235769e+05
# 20036.0  4.015452e+05
# 20037.0  6.124601e+05
# 20052.0  5.378571e+05
# 20392.0  3.489169e+05

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[(df['PRICE'] <= 400000) & (df['BEDRM'] >= 4) & (df['BATHRM'] >= 3)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 169            169       3          0     Forced Air  Y        3.0     10
# 255            255       3          1      Warm Cool  Y        2.0      8
# 335            335       4          0  Hot Water Rad  Y        2.0      6
# 353            353       4          0      Warm Cool  Y        4.0      9
# 362            362       3          1  Hot Water Rad  Y        2.0     11
# 423            423       3          0      Warm Cool  Y        2.0      8
# 516            516       3          1     Forced Air  Y        2.0     10
# 602            602       3          1  Hot Water Rad  N        1.0      8
# 693            693       5          0      Warm Cool  Y        2.0     16
# 742            742       3          1      Warm Cool  Y        2.0      9
# 744            744       4          0  Hot Water Rad  N        4.0     14
# ...

# %%
df.drop(['Unnamed: 0','AYB','YR_RMDL','SALE_NUM','GIS_LAST_MOD_DTTM', 'USECODE', 'CMPLX_NUM','LIVING_GBA','CITY','SOURCE','NATIONALGRID',
       'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
       'CENSUS_TRACT', 'CENSUS_BLOCK','SQUARE', 'X', 'Y', 'QUADRANT'], axis = 1)
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM   EYB  \
# 0            4          0      Warm Cool  Y        2.0      8      4  1972
# 1            3          1      Warm Cool  Y        2.0     11      5  1972
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1984
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1984
# 4            2          1      Warm Cool  Y        1.0     11      3  1985
# 5            3          2  Hot Water Rad  Y        1.0     10      5  1972
# 6            1          0      Warm Cool  Y        2.0      5      2  1957
# 7            3          1  Hot Water Rad  Y        2.0      8      4  1972
# 8            3          1      Warm Cool  Y        2.0      7      3  1967
# 9            1          1  Hot Water Rad  Y        1.0      6      2  1950
# 10           3          0     Forced Air  N        3.0     12      5  1954
# ...

# %%
df[(df['PRICE'] <= 400000) & (df['BEDRM'] >= 4) & (df['BATHRM'] >= 3)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 169            169       3          0     Forced Air  Y        3.0     10
# 255            255       3          1      Warm Cool  Y        2.0      8
# 335            335       4          0  Hot Water Rad  Y        2.0      6
# 353            353       4          0      Warm Cool  Y        4.0      9
# 362            362       3          1  Hot Water Rad  Y        2.0     11
# 423            423       3          0      Warm Cool  Y        2.0      8
# 516            516       3          1     Forced Air  Y        2.0     10
# 602            602       3          1  Hot Water Rad  N        1.0      8
# 693            693       5          0      Warm Cool  Y        2.0     16
# 742            742       3          1      Warm Cool  Y        2.0      9
# 744            744       4          0  Hot Water Rad  N        4.0     14
# ...

# %% [markdown]
#                                             Data Visualtization of DC Properties dataset  (Turn In for 3rd Class Session)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.lmplot(x='ZIPCODE', y='PRICE', data=df)
# Out:
# C:\Users\D\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='BEDRM', y='PRICE', data=df)

# %%
sns.boxplot(data=df)

# %%
df = df.drop(['Unnamed: 0','AYB','YR_RMDL','SALE_NUM','GIS_LAST_MOD_DTTM', 'USECODE', 'CMPLX_NUM','LIVING_GBA','CITY','SOURCE','NATIONALGRID',
       'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
       'CENSUS_TRACT', 'CENSUS_BLOCK','SQUARE', 'X', 'Y', 'QUADRANT'], axis = 1)

# %%
df.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM   EYB  \
# 0       4          0      Warm Cool  Y        2.0      8      4  1972
# 1       3          1      Warm Cool  Y        2.0     11      5  1972
# 2       3          1  Hot Water Rad  Y        2.0      9      5  1984
# 3       3          1  Hot Water Rad  Y        2.0      8      5  1984
# 4       2          1      Warm Cool  Y        1.0     11      3  1985
#
#    STORIES             SALEDATE   ...         EXTWALL        ROOF   INTWALL  \
# 0      3.0  2003-11-25 00:00:00   ...    Common Brick  Metal- Sms  Hardwood
# 1      3.0  2000-08-17 00:00:00   ...    Common Brick    Built Up  Hardwood
# 2      3.0  2016-06-21 00:00:00   ...    Common Brick    Built Up  Hardwood
# 3      3.0  2006-07-12 00:00:00   ...    Common Brick    Built Up  Hardwood
# 4      3.0                  NaN   ...    Common Brick     Neopren  Hardwood
#
#    KITCHENS FIREPLACES LANDAREA                   FULLADDRESS STATE  ZIPCODE  \
# ...

# %% [markdown]
#                                             Violin Plot : DC Property Sales Data reflecting Rooms data by Ward

# %%
sns.violinplot(x='WARD', y='ROOMS', data=df)

# %% [markdown]
#                                             Violin Plt : DC Property Sales Data refelcting Bedrooms data by Ward

# %%
sns.violinplot(x='WARD', y='BEDRM', data=df)

# %%
sns.swarmplot(x='WARD', y='BEDRM', data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-7456434cec7a> in <module>
# ----> 1 sns.swarmplot(x='WARD', y='BEDRM', data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2989                        linewidth=linewidth))
#    2990
# -> 2991     plotter.plot(ax, kwargs)
#    2992     return ax
#    2993
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1444     def plot(self, ax, kws):
#    1445         """Make the full plot."""
# -> 1446         self.draw_swarmplot(ax, kws)
#    1447         self.add_legend_data(ax)
#    1448         self.annotate_axes(ax)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
# ...

# %%
df = df.drop(['NUM_UNITS','SALEDATE','QUALIFIED','GBA','BLDG_NUM','STRUCT', 'GRADE','EXTWALL', 'ROOF', 'INTWALL','FULLADDRESS', 'STATE'], axis = 1)

# %% [markdown]
#                                     Heat Map : DC Property Sales Data

# %%
corr = df.corr()
sns.heatmap(corr, vmin=-1, annot=True)

# %% [markdown]
#                                             Box & Whisker Plot : DC Property Sales Data reflecting Bedrooms data per Ward

# %%
sns.boxplot(x='WARD', y='BEDRM', data=df)
